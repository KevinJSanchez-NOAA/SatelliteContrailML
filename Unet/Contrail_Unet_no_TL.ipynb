# %% [markdown]
# <a name='1'></a>
# ## Import Packages and load data

# %%
### -*- coding: utf-8 -*-
"""
Created on Mon May 24 13:26:13 2021

@author: kjsanche

Description: 
A function to load the 5 minute granules from MODIS channel 1 
(0.65 microns) and the contrail mask for ML with a CNN.

To do:

-organize/markdown/comment code


Input:
Path   (string)
 
        
        
Output:
MODISCh1 (2D uint32)
MASK     (2D uint16)
"""


from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import struct
import os
import glob
import random
#from format_input import *
from UNET_Functions import unet_model, summary
from Sat_contrail_read import Extract_RawDef, extract_img, extract_mask, extract_imglist, get_model_memory_usage
import tensorflow as tf
import sys
sys.path.append('/home/kjsanche/Desktop/Projects/loss')
from loss_function import *
from tensorflow.python.ops.metrics_impl import false_positives, false_negatives
import tensorflow.keras.metrics as tfm
import tensorflow_addons as tfa
from focal_loss import BinaryFocalLoss, SparseCategoricalFocalLoss


#config = tf.config.experimental
#config.gpu_options.allow_growth = True
#sess = tf.Session(config=config)

sys_details = tf.sysconfig.get_build_info()
print(sys_details)
cudnn_version = sys_details["cudnn_version"]
cuda_version = sys_details["cuda_version"]

print('cuda version: ', cuda_version)
print('cudNN version: ',cudnn_version)
print('TF version: ', tf.version.VERSION)




VALIDATION_SPLIT = .2
BATCH_SIZE = 32
EPOCHS = 3000
AUTO = tf.data.experimental.AUTOTUNE # used in tf.data.Dataset API
IMG_W=64
IMG_H=64
N_CHANNELS = 7
LEARNING_RATE = 0.00003
TFrecord_path ='/home/kjsanche/Desktop/ExternalSSD/SatContrailData/TFrecords/'
Models_path ='/home/kjsanche/Desktop/ExternalSSD/SatContrailData/Models/'
#TFrecord_path = '/home/kjsanche/Desktop/Projects/Sat_Contrail_Unet/Unet/content/'
filenames=tf.io.gfile.glob([TFrecord_path + '*v25*.tfrecords'])


random.shuffle(filenames)
split_training = int(len(filenames) * VALIDATION_SPLIT*2)
split_val = int(len(filenames) * VALIDATION_SPLIT)

#training_filenames = filenames[split_training:]
#validation_filenames = filenames[:split_val]
#test_filenames = filenames[split_val:split_training]

training_filenames = filenames[split_val:]
validation_filenames = filenames[:split_val]
test_filenames = filenames[:split_val]

validation_steps = len(validation_filenames) // BATCH_SIZE
test_steps = len(test_filenames) // BATCH_SIZE
steps_per_epoch = len(training_filenames)  // BATCH_SIZE
# Out:
# OrderedDict([('cpu_compiler', '/home/builder/ktietz/aggregate/tensorflow_recipes/ci_cpu/tensorflow-base_1614583966145/_build_env/bin/x86_64-conda_cos6-linux-gnu-gcc'), ('cuda_compute_capabilities', ['compute_35', 'compute_52', 'compute_60', 'compute_61', 'compute_70', 'compute_75']), ('cuda_version', '10.1'), ('cudnn_version', '7'), ('is_cuda_build', True), ('is_rocm_build', False)])
# cuda version:  10.1
# cudNN version:  7
# TF version:  2.4.1

# %%
def parse_tfr_element(element):
    #use the same structure as above; it's kinda an outline of the structure we now want to create
    data = {
      'height': tf.io.FixedLenFeature([], tf.int64),
      'width':tf.io.FixedLenFeature([], tf.int64),
      'depth':tf.io.FixedLenFeature([], tf.int64),
      'raw_label':tf.io.FixedLenFeature([], tf.string),#tf.string = bytestring (not text string)
      'raw_image' : tf.io.FixedLenFeature([], tf.string),#tf.string = bytestring (not text string)
    }


    content = tf.io.parse_single_example(element, data)

    height = content['height']
    #height=1024
    width = content['width']
    #width=1024*2
    depth = content['depth']
    #depth=7
    raw_label = content['raw_label']
    raw_image = content['raw_image']


    #get our 'feature'-- our image -- and reshape it appropriately
    feature = tf.io.parse_tensor(raw_image, out_type=tf.float16)

    feature = tf.reshape(feature, shape=[height,width,depth])
    label = tf.io.parse_tensor(raw_label, out_type=tf.int8)
    label = tf.reshape(label, shape=[height,width])
    return (feature, label)

def get_batched_dataset(filenames):
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.Dataset.list_files(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.interleave(tf.data.TFRecordDataset, cycle_length=16, num_parallel_calls=AUTO)
    dataset = dataset.map(parse_tfr_element, num_parallel_calls=AUTO)

    dataset = dataset.cache() # This dataset fits in RAM
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True) 
    dataset = dataset.prefetch(AUTO) #

    return dataset

def get_training_dataset(training_filenames):
    return get_batched_dataset(training_filenames)

def get_validation_dataset(validation_filenames):
    return get_batched_dataset(validation_filenames)

def get_test_dataset(test_filenames):
    return get_batched_dataset(test_filenames)

def get_dataset_large(tfr_dir:str="/home/kjsanche/Desktop/Projects/Sat_Contrail_Unet/Unet/content/", pattern:str="*large_images.tfrecords"):
    files = glob.glob(tfr_dir+pattern, recursive=False)

    #create the dataset
    dataset = tf.data.TFRecordDataset(files)

    #pass every single feature through our mapping function
    dataset = dataset.map(parse_tfr_element)

    return dataset
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        #print(i)
        #print(display_list[i].shape)
        if i == 0:
            plt.imshow(np.float32(display_list[i][:,:,7]))#-display_list[i][:,:,1]))
        else:
            plt.imshow(np.float32(1*display_list[i]))
        plt.axis('off')
    plt.show()

# %% [markdown]
# The below code cell uses a lot of memory and therefore should only be used for testing and not be used during training.

# %% [raw]
# testdataset = get_dataset_large(tfr_dir = TFrecord_path, pattern = '*.tfrecords')
# for image, mask in testdataset.take(3):
#     sample_image, sample_mask = image, mask
#     display([sample_image, sample_mask])
# print('mem usage: ', tf.config.experimental.get_memory_usage("GPU:0"))

# %%
def FocalTverskyLoss(targets, inputs, alpha=0.5, beta=0.5, gamma=1, smooth=1e-6):
        '''
        ... in the case of α=β=0.5 the Tversky index simplifies to be 
        the same as the Dice coefficient, which is also equal to the F1 
        score. With α=β=1, Equation 2 produces Tanimoto coefficient, and 
        setting α+β=1 produces the set of Fβ scores. Larger βs weigh 
        recall higher than precision (by placing more emphasis on false negatives).
        '''
        targets = tf.cast(targets,tf.float32)
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky

# %% [raw]
# class FalsePositives(tfm.FalsePositives):
#     def __init__(self, from_logits=False, *args, **kwargs):
#         super().__init__(*args, **kwargs)
#         self._from_logits = from_logits
#
#     def update_state(self, y_true, y_pred, sample_weight=None):
#         if self._from_logits:
#             super(FalsePositives, self).update_state(y_true, tf.nn.sigmoid(y_pred), sample_weight)
#         else:
#             super(FalsePositives, self).update_state(y_true, y_pred, sample_weight)

# %%
#gamma>1 reduces the relative loss for well-classified examples 
#alpha is a weighted term whose value is α for positive(foreground) alpha = 1 does nothing. alpha = 0.25 is best
#class and 1-α for negative(background) class.

unet = unet_model((IMG_W, IMG_H, N_CHANNELS),n_filters=32,n_classes=1)
#loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#loss=tfa.losses.SigmoidFocalCrossEntropy(),
#loss=[BinaryFocalLoss(gamma=2,from_logits=True)],

#Larger βs weigh recall higher than precision (by placing more emphasis on false negatives)
#loss=FocalTverskyLoss(targets, inputs, alpha=0.5, beta=0.5, gamma=1, smooth=1e-6)
unet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss=[FocalTverskyLoss],
              metrics=[tfm.Precision(), tfm.Recall(), tfm.FalseNegatives(), tfm.FalsePositives(), tfm.TruePositives(), tfm.TrueNegatives(), 'binary_accuracy'])

unet.summary(line_length = 130)
print('mem usage: ', tf.config.experimental.get_memory_usage("GPU:0"))
# Out:
# Model: "model"
# __________________________________________________________________________________________________________________________________
# Layer (type)                              Output Shape                 Param #         Connected to
# ==================================================================================================================================
# input_1 (InputLayer)                      [(None, 64, 64, 7)]          0
# __________________________________________________________________________________________________________________________________
# conv2d (Conv2D)                           (None, 64, 64, 32)           2048            input_1[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)                   (None, 64, 64, 32)           0               conv2d[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_1 (Conv2D)                         (None, 64, 64, 32)           9248            leaky_re_lu[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)                 (None, 64, 64, 32)           0               conv2d_1[0][0]
# __________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)              (None, 32, 32, 32)           0               leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_2 (Conv2D)                         (None, 32, 32, 64)           18496           max_pooling2d[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)                 (None, 32, 32, 64)           0               conv2d_2[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_3 (Conv2D)                         (None, 32, 32, 64)           36928           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)                 (None, 32, 32, 64)           0               conv2d_3[0][0]
# __________________________________________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)            (None, 16, 16, 64)           0               leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_4 (Conv2D)                         (None, 16, 16, 128)          73856           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)                 (None, 16, 16, 128)          0               conv2d_4[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_5 (Conv2D)                         (None, 16, 16, 128)          147584          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)                 (None, 16, 16, 128)          0               conv2d_5[0][0]
# __________________________________________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)            (None, 8, 8, 128)            0               leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_6 (Conv2D)                         (None, 8, 8, 256)            295168          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)                 (None, 8, 8, 256)            0               conv2d_6[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_7 (Conv2D)                         (None, 8, 8, 256)            590080          leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)                 (None, 8, 8, 256)            0               conv2d_7[0][0]
# __________________________________________________________________________________________________________________________________
# dropout (Dropout)                         (None, 8, 8, 256)            0               leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)            (None, 4, 4, 256)            0               dropout[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_8 (Conv2D)                         (None, 4, 4, 512)            1180160         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)                 (None, 4, 4, 512)            0               conv2d_8[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_9 (Conv2D)                         (None, 4, 4, 512)            2359808         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)                 (None, 4, 4, 512)            0               conv2d_9[0][0]
# __________________________________________________________________________________________________________________________________
# dropout_1 (Dropout)                       (None, 4, 4, 512)            0               leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspose)        (None, 8, 8, 256)            1179904         dropout_1[0][0]
# __________________________________________________________________________________________________________________________________
# concatenate (Concatenate)                 (None, 8, 8, 512)            0               conv2d_transpose[0][0]
#                                                                                        dropout[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_10 (Conv2D)                        (None, 8, 8, 256)            1179904         concatenate[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)                (None, 8, 8, 256)            0               conv2d_10[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_11 (Conv2D)                        (None, 8, 8, 256)            590080          leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)                (None, 8, 8, 256)            0               conv2d_11[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTranspose)      (None, 16, 16, 128)          295040          leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)               (None, 16, 16, 256)          0               conv2d_transpose_1[0][0]
#                                                                                        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_12 (Conv2D)                        (None, 16, 16, 128)          295040          concatenate_1[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)                (None, 16, 16, 128)          0               conv2d_12[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_13 (Conv2D)                        (None, 16, 16, 128)          147584          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)                (None, 16, 16, 128)          0               conv2d_13[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTranspose)      (None, 32, 32, 64)           73792           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________________________________________
# concatenate_2 (Concatenate)               (None, 32, 32, 128)          0               conv2d_transpose_2[0][0]
#                                                                                        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_14 (Conv2D)                        (None, 32, 32, 64)           73792           concatenate_2[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)                (None, 32, 32, 64)           0               conv2d_14[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_15 (Conv2D)                        (None, 32, 32, 64)           36928           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)                (None, 32, 32, 64)           0               conv2d_15[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTranspose)      (None, 64, 64, 32)           18464           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________________________________________
# concatenate_3 (Concatenate)               (None, 64, 64, 64)           0               conv2d_transpose_3[0][0]
#                                                                                        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_16 (Conv2D)                        (None, 64, 64, 32)           18464           concatenate_3[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)                (None, 64, 64, 32)           0               conv2d_16[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_17 (Conv2D)                        (None, 64, 64, 32)           9248            leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)                (None, 64, 64, 32)           0               conv2d_17[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_18 (Conv2D)                        (None, 64, 64, 32)           9248            leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)                (None, 64, 64, 32)           0               conv2d_18[0][0]
# __________________________________________________________________________________________________________________________________
# conv2d_19 (Conv2D)                        (None, 64, 64, 1)            33              leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________________________________________
# tf.compat.v1.squeeze (TFOpLambda)         (None, 64, 64)               0               conv2d_19[0][0]
# __________________________________________________________________________________________________________________________________
# tf.math.sigmoid (TFOpLambda)              (None, 64, 64)               0               tf.compat.v1.squeeze[0][0]
# ==================================================================================================================================
# Total params: 8,640,897
# Trainable params: 8,640,897
# Non-trainable params: 0
# __________________________________________________________________________________________________________________________________
# mem usage:  34574848

# %%
print(get_model_memory_usage(BATCH_SIZE, unet))

#callback = tf.keras.callbacks.EarlyStopping(monitor='val_mean_io_u', patience=100)
training_data = get_training_dataset(training_filenames)
validation_data = get_validation_dataset(validation_filenames)
test_data = get_test_dataset(test_filenames)
print(training_data)
model_history = unet.fit(training_data, validation_data=validation_data, validation_steps=validation_steps, steps_per_epoch=steps_per_epoch, epochs=EPOCHS)
# Out:
# 0.405
# WARNING:tensorflow:AutoGraph could not transform <function parse_tfr_element at 0x7f00cf883670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function parse_tfr_element at 0x7f00cf883670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# <PrefetchDataset shapes: ((32, None, None, None), (32, None, None)), types: (tf.float16, tf.int8)>
# Epoch 1/3000
# 74/74 [==============================] - 57s 123ms/step - loss: 0.9881 - precision: 0.0045 - recall: 0.1864 - false_negatives: 16682.8667 - false_positives: 524045.4000 - true_positives: 2450.1467 - true_negatives: 4435809.9600 - binary_accuracy: 0.8509 - val_loss: 0.9830 - val_precision: 0.0063 - val_recall: 0.0227 - val_false_negatives: 11087.0000 - val_false_positives: 40396.0000 - val_true_positives: 258.0000 - val_true_negatives: 2307555.0000 - val_binary_accuracy: 0.9782
# Epoch 2/3000
# 74/74 [==============================] - 8s 108ms/step - loss: 0.9810 - precision: 0.0105 - recall: 0.0572 - false_negatives: 22752.5067 - false_positives: 142094.8267 - true_positives: 1485.0000 - true_negatives: 4812656.0400 - binary_accuracy: 0.9690 - val_loss: 0.9813 - val_precision: 0.0109 - val_recall: 0.1069 - val_false_negatives: 10807.0000 - val_false_positives: 116855.0000 - val_true_positives: 1293.0000 - val_true_negatives: 2230341.0000 - val_binary_accuracy: 0.9459
# Epoch 3/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9796 - precision: 0.0126 - recall: 0.1597 - false_negatives: 22224.9600 - false_positives: 387001.5600 - true_positives: 5146.8533 - true_negatives: 4564615.0000 - binary_accuracy: 0.9280 - val_loss: 0.9801 - val_precision: 0.0156 - val_recall: 0.5143 - val_false_negatives: 5719.0000 - val_false_positives: 382562.0000 - val_true_positives: 6055.0000 - val_true_negatives: 1964960.0000 - val_binary_accuracy: 0.8354
# Epoch 4/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9780 - precision: 0.0123 - recall: 0.4017 - false_negatives: 15573.3733 - false_positives: 911826.6933 - true_positives: 10667.5067 - true_negatives: 4040920.8000 - binary_accuracy: 0.8135 - val_loss: 0.9719 - val_precision: 0.0161 - val_recall: 0.6120 - val_false_negatives: 6007.0000 - val_false_positives: 580306.0000 - val_true_positives: 9474.0000 - val_true_negatives: 1763509.0000 - val_binary_accuracy: 0.7515
# Epoch 5/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9761 - precision: 0.0146 - recall: 0.4998 - false_negatives: 12792.7867 - false_positives: 850549.5867 - true_positives: 11211.8933 - true_negatives: 4104434.1067 - binary_accuracy: 0.8243 - val_loss: 0.9844 - val_precision: 0.0085 - val_recall: 0.4780 - val_false_negatives: 4425.0000 - val_false_positives: 474250.0000 - val_true_positives: 4052.0000 - val_true_negatives: 1876569.0000 - val_binary_accuracy: 0.7971
# Epoch 6/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9669 - precision: 0.0196 - recall: 0.4622 - false_negatives: 17706.2800 - false_positives: 703145.6667 - true_positives: 12933.0267 - true_negatives: 4245203.4000 - binary_accuracy: 0.8471 - val_loss: 0.9569 - val_precision: 0.0311 - val_recall: 0.3036 - val_false_negatives: 13861.0000 - val_false_positives: 188257.0000 - val_true_positives: 6042.0000 - val_true_negatives: 2151136.0000 - val_binary_accuracy: 0.9143
# Epoch 7/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9669 - precision: 0.0197 - recall: 0.1804 - false_negatives: 26070.8667 - false_positives: 300953.1867 - true_positives: 7187.3867 - true_negatives: 4644776.9333 - binary_accuracy: 0.9362 - val_loss: 0.9749 - val_precision: 0.0155 - val_recall: 0.2408 - val_false_negatives: 10984.0000 - val_false_positives: 221096.0000 - val_true_positives: 3483.0000 - val_true_negatives: 2123733.0000 - val_binary_accuracy: 0.9016
# Epoch 8/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9677 - precision: 0.0165 - recall: 0.3122 - false_negatives: 20527.9200 - false_positives: 547605.5067 - true_positives: 9055.8800 - true_negatives: 4401799.0667 - binary_accuracy: 0.8852 - val_loss: 0.9670 - val_precision: 0.0217 - val_recall: 0.4299 - val_false_negatives: 7440.0000 - val_false_positives: 252712.0000 - val_true_positives: 5610.0000 - val_true_negatives: 2093534.0000 - val_binary_accuracy: 0.8897
# Epoch 9/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9763 - precision: 0.0127 - recall: 0.2447 - false_negatives: 21974.2667 - false_positives: 516194.2000 - true_positives: 6903.6667 - true_negatives: 4433916.2400 - binary_accuracy: 0.8911 - val_loss: 0.9720 - val_precision: 0.0164 - val_recall: 0.3830 - val_false_negatives: 9092.0000 - val_false_positives: 338238.0000 - val_true_positives: 5645.0000 - val_true_negatives: 2006321.0000 - val_binary_accuracy: 0.8528
# Epoch 10/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9685 - precision: 0.0161 - recall: 0.3958 - false_negatives: 16505.4000 - false_positives: 693563.1067 - true_positives: 11209.3333 - true_negatives: 4257710.5333 - binary_accuracy: 0.8548 - val_loss: 0.9853 - val_precision: 0.0084 - val_recall: 0.1812 - val_false_negatives: 8026.0000 - val_false_positives: 209267.0000 - val_true_positives: 1776.0000 - val_true_negatives: 2140227.0000 - val_binary_accuracy: 0.9079
# Epoch 11/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9688 - precision: 0.0202 - recall: 0.3173 - false_negatives: 18817.9733 - false_positives: 426351.4267 - true_positives: 9966.5733 - true_negatives: 4523852.4000 - binary_accuracy: 0.9038 - val_loss: 0.9722 - val_precision: 0.0139 - val_recall: 0.1526 - val_false_negatives: 12011.0000 - val_false_positives: 153564.0000 - val_true_positives: 2163.0000 - val_true_negatives: 2191558.0000 - val_binary_accuracy: 0.9298
# Epoch 12/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9756 - precision: 0.0154 - recall: 0.1717 - false_negatives: 21658.1333 - false_positives: 267278.9600 - true_positives: 4481.3467 - true_negatives: 4685569.9333 - binary_accuracy: 0.9345 - val_loss: 0.9524 - val_precision: 0.0320 - val_recall: 0.2239 - val_false_negatives: 11424.0000 - val_false_positives: 99654.0000 - val_true_positives: 3296.0000 - val_true_negatives: 2244922.0000 - val_binary_accuracy: 0.9529
# Epoch 13/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9813 - precision: 0.0153 - recall: 0.1258 - false_negatives: 22120.3333 - false_positives: 205528.0267 - true_positives: 3924.7867 - true_negatives: 4747415.2267 - binary_accuracy: 0.9543 - val_loss: 0.9870 - val_precision: 0.0085 - val_recall: 0.1783 - val_false_negatives: 6848.0000 - val_false_positives: 174192.0000 - val_true_positives: 1486.0000 - val_true_negatives: 2176770.0000 - val_binary_accuracy: 0.9233
# Epoch 14/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9729 - precision: 0.0151 - recall: 0.2728 - false_negatives: 20509.8267 - false_positives: 491004.2667 - true_positives: 7487.8667 - true_negatives: 4459986.4133 - binary_accuracy: 0.8893 - val_loss: 0.9801 - val_precision: 0.0094 - val_recall: 0.1301 - val_false_negatives: 9423.0000 - val_false_positives: 148032.0000 - val_true_positives: 1409.0000 - val_true_negatives: 2200432.0000 - val_binary_accuracy: 0.9333
# Epoch 15/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9634 - precision: 0.0262 - recall: 0.2335 - false_negatives: 21567.5867 - false_positives: 195752.2400 - true_positives: 4668.7333 - true_negatives: 4756999.8133 - binary_accuracy: 0.9500 - val_loss: 0.9713 - val_precision: 0.0188 - val_recall: 0.3883 - val_false_negatives: 7657.0000 - val_false_positives: 253101.0000 - val_true_positives: 4861.0000 - val_true_negatives: 2093677.0000 - val_binary_accuracy: 0.8895
# Epoch 16/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9681 - precision: 0.0208 - recall: 0.1885 - false_negatives: 26874.0800 - false_positives: 246026.7867 - true_positives: 4945.1600 - true_negatives: 4701142.3467 - binary_accuracy: 0.9418 - val_loss: 0.9491 - val_precision: 0.0322 - val_recall: 0.2732 - val_false_negatives: 11095.0000 - val_false_positives: 125294.0000 - val_true_positives: 4171.0000 - val_true_negatives: 2218736.0000 - val_binary_accuracy: 0.9422
# Epoch 17/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9718 - precision: 0.0223 - recall: 0.1615 - false_negatives: 18381.6400 - false_positives: 161057.7733 - true_positives: 3574.2267 - true_negatives: 4795974.7333 - binary_accuracy: 0.9643 - val_loss: 0.9377 - val_precision: 0.0634 - val_recall: 0.1504 - val_false_negatives: 15336.0000 - val_false_positives: 40098.0000 - val_true_positives: 2715.0000 - val_true_negatives: 2301147.0000 - val_binary_accuracy: 0.9765
# Epoch 18/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9686 - precision: 0.0207 - recall: 0.1189 - false_negatives: 22735.9333 - false_positives: 161849.2667 - true_positives: 3459.2133 - true_negatives: 4790943.9600 - binary_accuracy: 0.9646 - val_loss: 0.9765 - val_precision: 0.0128 - val_recall: 0.1852 - val_false_negatives: 9960.0000 - val_false_positives: 173973.0000 - val_true_positives: 2264.0000 - val_true_negatives: 2173099.0000 - val_binary_accuracy: 0.9220
# Epoch 19/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9615 - precision: 0.0210 - recall: 0.2212 - false_negatives: 20726.0533 - false_positives: 245958.3200 - true_positives: 6185.8400 - true_negatives: 4706118.1600 - binary_accuracy: 0.9396 - val_loss: 0.9816 - val_precision: 0.0108 - val_recall: 0.0968 - val_false_negatives: 12328.0000 - val_false_positives: 120843.0000 - val_true_positives: 1321.0000 - val_true_negatives: 2224804.0000 - val_binary_accuracy: 0.9436
# Epoch 20/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9603 - precision: 0.0301 - recall: 0.2034 - false_negatives: 20263.3067 - false_positives: 152812.7733 - true_positives: 4815.9733 - true_negatives: 4801096.3200 - binary_accuracy: 0.9642 - val_loss: 0.9618 - val_precision: 0.0267 - val_recall: 0.1685 - val_false_negatives: 10669.0000 - val_false_positives: 78676.0000 - val_true_positives: 2162.0000 - val_true_negatives: 2267789.0000 - val_binary_accuracy: 0.9621
# Epoch 21/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9625 - precision: 0.0221 - recall: 0.2039 - false_negatives: 22131.8533 - false_positives: 284354.9733 - true_positives: 6538.0533 - true_negatives: 4665963.4933 - binary_accuracy: 0.9449 - val_loss: 0.9731 - val_precision: 0.0131 - val_recall: 0.2568 - val_false_negatives: 7406.0000 - val_false_positives: 192994.0000 - val_true_positives: 2559.0000 - val_true_negatives: 2156337.0000 - val_binary_accuracy: 0.9151
# Epoch 22/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9773 - precision: 0.0109 - recall: 0.2217 - false_negatives: 15948.0933 - false_positives: 418642.0133 - true_positives: 5221.4000 - true_negatives: 4539176.8667 - binary_accuracy: 0.9121 - val_loss: 0.9857 - val_precision: 0.0070 - val_recall: 0.1366 - val_false_negatives: 8612.0000 - val_false_positives: 192021.0000 - val_true_positives: 1363.0000 - val_true_negatives: 2157300.0000 - val_binary_accuracy: 0.9150
# Epoch 23/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9561 - precision: 0.0322 - recall: 0.3157 - false_negatives: 16243.2133 - false_positives: 183075.8000 - true_positives: 5734.0533 - true_negatives: 4773935.3067 - binary_accuracy: 0.9536 - val_loss: 0.9368 - val_precision: 0.0419 - val_recall: 0.3341 - val_false_negatives: 11448.0000 - val_false_positives: 131214.0000 - val_true_positives: 5745.0000 - val_true_negatives: 2210889.0000 - val_binary_accuracy: 0.9395
# Epoch 24/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9677 - precision: 0.0336 - recall: 0.1693 - false_negatives: 15486.5733 - false_positives: 80790.8933 - true_positives: 2728.8933 - true_negatives: 4879982.0133 - binary_accuracy: 0.9773 - val_loss: 0.9716 - val_precision: 0.0671 - val_recall: 0.1263 - val_false_negatives: 8226.0000 - val_false_positives: 16541.0000 - val_true_positives: 1189.0000 - val_true_negatives: 2333340.0000 - val_binary_accuracy: 0.9895
# Epoch 25/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9615 - precision: 0.0262 - recall: 0.1754 - false_negatives: 17242.5467 - false_positives: 155370.7600 - true_positives: 3758.8800 - true_negatives: 4802616.1867 - binary_accuracy: 0.9686 - val_loss: 0.9675 - val_precision: 0.0264 - val_recall: 0.2804 - val_false_negatives: 10302.0000 - val_false_positives: 147851.0000 - val_true_positives: 4014.0000 - val_true_negatives: 2197129.0000 - val_binary_accuracy: 0.9330
# Epoch 26/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9664 - precision: 0.0189 - recall: 0.3451 - false_negatives: 15606.1067 - false_positives: 370211.3467 - true_positives: 6988.7867 - true_negatives: 4586182.1333 - binary_accuracy: 0.9213 - val_loss: 0.9399 - val_precision: 0.0415 - val_recall: 0.3570 - val_false_negatives: 9359.0000 - val_false_positives: 119909.0000 - val_true_positives: 5197.0000 - val_true_negatives: 2224831.0000 - val_binary_accuracy: 0.9452
# Epoch 27/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9618 - precision: 0.0270 - recall: 0.2168 - false_negatives: 23108.9733 - false_positives: 202584.2800 - true_positives: 5385.8000 - true_negatives: 4747909.3200 - binary_accuracy: 0.9530 - val_loss: 0.9543 - val_precision: 0.0255 - val_recall: 0.4213 - val_false_negatives: 8141.0000 - val_false_positives: 226831.0000 - val_true_positives: 5926.0000 - val_true_negatives: 2118398.0000 - val_binary_accuracy: 0.9004
# Epoch 28/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9623 - precision: 0.0213 - recall: 0.2827 - false_negatives: 18957.1467 - false_positives: 311473.0000 - true_positives: 7051.4667 - true_negatives: 4641506.7600 - binary_accuracy: 0.9236 - val_loss: 0.9520 - val_precision: 0.0392 - val_recall: 0.2023 - val_false_negatives: 9038.0000 - val_false_positives: 56131.0000 - val_true_positives: 2292.0000 - val_true_negatives: 2291835.0000 - val_binary_accuracy: 0.9724
# Epoch 29/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9427 - precision: 0.0443 - recall: 0.2272 - false_negatives: 20599.1067 - false_positives: 157207.4000 - true_positives: 6519.2533 - true_negatives: 4794662.6133 - binary_accuracy: 0.9671 - val_loss: 0.9445 - val_precision: 0.0390 - val_recall: 0.2628 - val_false_negatives: 10600.0000 - val_false_positives: 92994.0000 - val_true_positives: 3778.0000 - val_true_negatives: 2251924.0000 - val_binary_accuracy: 0.9561
# Epoch 30/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9388 - precision: 0.0474 - recall: 0.2182 - false_negatives: 19049.2133 - false_positives: 98518.7733 - true_positives: 4712.5467 - true_negatives: 4856707.8400 - binary_accuracy: 0.9773 - val_loss: 0.9529 - val_precision: 0.0209 - val_recall: 0.1555 - val_false_negatives: 8641.0000 - val_false_positives: 74563.0000 - val_true_positives: 1591.0000 - val_true_negatives: 2274501.0000 - val_binary_accuracy: 0.9647
# Epoch 31/3000
# 74/74 [==============================] - 8s 107ms/step - loss: 0.9533 - precision: 0.0309 - recall: 0.2256 - false_negatives: 21746.9467 - false_positives: 247258.1333 - true_positives: 7368.5733 - true_negatives: 4702614.7200 - binary_accuracy: 0.9502 - val_loss: 0.9727 - val_precision: 0.0170 - val_recall: 0.1767 - val_false_negatives: 6969.0000 - val_false_positives: 86428.0000 - val_true_positives: 1496.0000 - val_true_negatives: 2264403.0000 - val_binary_accuracy: 0.9604
# Epoch 32/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.9669 - precision: 0.0214 - recall: 0.2629 - false_negatives: 16222.0800 - false_positives: 298393.0000 - true_positives: 5971.6000 - true_negatives: 4658401.6933 - binary_accuracy: 0.9405 - val_loss: 0.9310 - val_precision: 0.0423 - val_recall: 0.1543 - val_false_negatives: 14675.0000 - val_false_positives: 60605.0000 - val_true_positives: 2677.0000 - val_true_negatives: 2281339.0000 - val_binary_accuracy: 0.9681
# Epoch 33/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9430 - precision: 0.0260 - recall: 0.4079 - false_negatives: 14749.3200 - false_positives: 649341.6667 - true_positives: 11836.2933 - true_negatives: 4303061.0933 - binary_accuracy: 0.8843 - val_loss: 0.9381 - val_precision: 0.0374 - val_recall: 0.3405 - val_false_negatives: 7966.0000 - val_false_positives: 105926.0000 - val_true_positives: 4113.0000 - val_true_negatives: 2241291.0000 - val_binary_accuracy: 0.9517
# Epoch 34/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9648 - precision: 0.0196 - recall: 0.2622 - false_negatives: 15030.1333 - false_positives: 260002.0667 - true_positives: 4888.1467 - true_negatives: 4699068.0267 - binary_accuracy: 0.9476 - val_loss: 0.9785 - val_precision: 0.0124 - val_recall: 0.1926 - val_false_negatives: 6238.0000 - val_false_positives: 118971.0000 - val_true_positives: 1488.0000 - val_true_negatives: 2232599.0000 - val_binary_accuracy: 0.9469
# Epoch 35/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9458 - precision: 0.0347 - recall: 0.2258 - false_negatives: 22076.2533 - false_positives: 164569.2400 - true_positives: 6170.8533 - true_negatives: 4786172.0267 - binary_accuracy: 0.9586 - val_loss: 0.9878 - val_precision: 0.0092 - val_recall: 0.0634 - val_false_negatives: 8900.0000 - val_false_positives: 65138.0000 - val_true_positives: 602.0000 - val_true_negatives: 2284656.0000 - val_binary_accuracy: 0.9686
# Epoch 36/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.9616 - precision: 0.0349 - recall: 0.1650 - false_negatives: 19339.6533 - false_positives: 109962.1467 - true_positives: 4309.9467 - true_negatives: 4845376.6267 - binary_accuracy: 0.9738 - val_loss: 0.9416 - val_precision: 0.0354 - val_recall: 0.1748 - val_false_negatives: 11979.0000 - val_false_positives: 69208.0000 - val_true_positives: 2538.0000 - val_true_negatives: 2275571.0000 - val_binary_accuracy: 0.9656
# Epoch 37/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9447 - precision: 0.0397 - recall: 0.2153 - false_negatives: 19757.8267 - false_positives: 135081.3067 - true_positives: 5150.1600 - true_negatives: 4818999.0800 - binary_accuracy: 0.9696 - val_loss: 0.9692 - val_precision: 0.0194 - val_recall: 0.2614 - val_false_negatives: 7420.0000 - val_false_positives: 132487.0000 - val_true_positives: 2626.0000 - val_true_negatives: 2216763.0000 - val_binary_accuracy: 0.9407
# Epoch 38/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9061 - precision: 0.0623 - recall: 0.3987 - false_negatives: 21524.5733 - false_positives: 166880.9867 - true_positives: 11006.6933 - true_negatives: 4779576.1200 - binary_accuracy: 0.9563 - val_loss: 0.9195 - val_precision: 0.0527 - val_recall: 0.2473 - val_false_negatives: 13544.0000 - val_false_positives: 79973.0000 - val_true_positives: 4450.0000 - val_true_negatives: 2261329.0000 - val_binary_accuracy: 0.9604
# Epoch 39/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9213 - precision: 0.0600 - recall: 0.2977 - false_negatives: 22200.7067 - false_positives: 139113.7600 - true_positives: 9500.3733 - true_negatives: 4808173.5333 - binary_accuracy: 0.9667 - val_loss: 0.9313 - val_precision: 0.0662 - val_recall: 0.1318 - val_false_negatives: 11539.0000 - val_false_positives: 24698.0000 - val_true_positives: 1752.0000 - val_true_negatives: 2321307.0000 - val_binary_accuracy: 0.9846
# Epoch 40/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.9500 - precision: 0.0454 - recall: 0.1120 - false_negatives: 23434.3333 - false_positives: 63316.5067 - true_positives: 3424.4133 - true_negatives: 4888813.1200 - binary_accuracy: 0.9837 - val_loss: 0.9587 - val_precision: 0.0299 - val_recall: 0.1538 - val_false_negatives: 9323.0000 - val_false_positives: 54977.0000 - val_true_positives: 1695.0000 - val_true_negatives: 2293301.0000 - val_binary_accuracy: 0.9727
# Epoch 41/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9361 - precision: 0.0454 - recall: 0.2437 - false_negatives: 21942.4800 - false_positives: 177292.4933 - true_positives: 7813.2133 - true_negatives: 4771940.1867 - binary_accuracy: 0.9630 - val_loss: 0.9178 - val_precision: 0.0501 - val_recall: 0.2699 - val_false_negatives: 11509.0000 - val_false_positives: 80715.0000 - val_true_positives: 4255.0000 - val_true_negatives: 2262817.0000 - val_binary_accuracy: 0.9609
# Epoch 42/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.9185 - precision: 0.0612 - recall: 0.2686 - false_negatives: 20046.3333 - false_positives: 114272.9333 - true_positives: 6618.5200 - true_negatives: 4838050.5867 - binary_accuracy: 0.9721 - val_loss: 0.8887 - val_precision: 0.0841 - val_recall: 0.3358 - val_false_negatives: 9640.0000 - val_false_positives: 53104.0000 - val_true_positives: 4873.0000 - val_true_negatives: 2291679.0000 - val_binary_accuracy: 0.9734
# Epoch 43/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9369 - precision: 0.0492 - recall: 0.2650 - false_negatives: 19156.7333 - false_positives: 137759.0133 - true_positives: 6916.9333 - true_negatives: 4815155.6933 - binary_accuracy: 0.9708 - val_loss: 0.9166 - val_precision: 0.0676 - val_recall: 0.1920 - val_false_negatives: 9483.0000 - val_false_positives: 31056.0000 - val_true_positives: 2253.0000 - val_true_negatives: 2316504.0000 - val_binary_accuracy: 0.9828
# Epoch 44/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9344 - precision: 0.0507 - recall: 0.1600 - false_negatives: 22443.5467 - false_positives: 81593.5600 - true_positives: 4447.0533 - true_negatives: 4870504.2133 - binary_accuracy: 0.9795 - val_loss: 0.8807 - val_precision: 0.0755 - val_recall: 0.3222 - val_false_negatives: 9091.0000 - val_false_positives: 52942.0000 - val_true_positives: 4321.0000 - val_true_negatives: 2292942.0000 - val_binary_accuracy: 0.9737
# Epoch 45/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.9192 - precision: 0.0548 - recall: 0.2168 - false_negatives: 22168.8133 - false_positives: 101047.3200 - true_positives: 6483.8933 - true_negatives: 4849288.3467 - binary_accuracy: 0.9744 - val_loss: 0.9026 - val_precision: 0.0659 - val_recall: 0.2312 - val_false_negatives: 11081.0000 - val_false_positives: 47239.0000 - val_true_positives: 3332.0000 - val_true_negatives: 2297644.0000 - val_binary_accuracy: 0.9753
# Epoch 46/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9021 - precision: 0.0885 - recall: 0.2444 - false_negatives: 22669.6267 - false_positives: 75004.7200 - true_positives: 7220.2933 - true_negatives: 4874093.7333 - binary_accuracy: 0.9799 - val_loss: 0.9173 - val_precision: 0.0577 - val_recall: 0.1840 - val_false_negatives: 11031.0000 - val_false_positives: 40634.0000 - val_true_positives: 2488.0000 - val_true_negatives: 2305143.0000 - val_binary_accuracy: 0.9781
# Epoch 47/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9393 - precision: 0.0425 - recall: 0.1593 - false_negatives: 20648.6000 - false_positives: 93166.4533 - true_positives: 4334.8933 - true_negatives: 4860838.4267 - binary_accuracy: 0.9768 - val_loss: 0.9170 - val_precision: 0.0730 - val_recall: 0.1373 - val_false_negatives: 13133.0000 - val_false_positives: 26539.0000 - val_true_positives: 2091.0000 - val_true_negatives: 2317533.0000 - val_binary_accuracy: 0.9832
# Epoch 48/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8795 - precision: 0.1014 - recall: 0.2070 - false_negatives: 25218.6400 - false_positives: 58789.6000 - true_positives: 6583.6667 - true_negatives: 4888396.4667 - binary_accuracy: 0.9828 - val_loss: 0.9224 - val_precision: 0.0684 - val_recall: 0.1717 - val_false_negatives: 8972.0000 - val_false_positives: 25344.0000 - val_true_positives: 1860.0000 - val_true_negatives: 2323120.0000 - val_binary_accuracy: 0.9855
# Epoch 49/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.8929 - precision: 0.0972 - recall: 0.2179 - false_negatives: 20264.5867 - false_positives: 55009.2400 - true_positives: 5630.7733 - true_negatives: 4898083.7733 - binary_accuracy: 0.9843 - val_loss: 0.8947 - val_precision: 0.0798 - val_recall: 0.2279 - val_false_negatives: 8074.0000 - val_false_positives: 27482.0000 - val_true_positives: 2383.0000 - val_true_negatives: 2321357.0000 - val_binary_accuracy: 0.9849
# Epoch 50/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8985 - precision: 0.0725 - recall: 0.2608 - false_negatives: 17054.7067 - false_positives: 65617.0400 - true_positives: 5535.2800 - true_negatives: 4890781.3467 - binary_accuracy: 0.9836 - val_loss: 0.8743 - val_precision: 0.1041 - val_recall: 0.2979 - val_false_negatives: 9198.0000 - val_false_positives: 33578.0000 - val_true_positives: 3902.0000 - val_true_negatives: 2312618.0000 - val_binary_accuracy: 0.9819
# Epoch 51/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.9073 - precision: 0.0838 - recall: 0.1885 - false_negatives: 22532.9867 - false_positives: 55411.2800 - true_positives: 5150.4667 - true_negatives: 4895893.6400 - binary_accuracy: 0.9838 - val_loss: 0.8752 - val_precision: 0.1045 - val_recall: 0.2364 - val_false_negatives: 8667.0000 - val_false_positives: 22997.0000 - val_true_positives: 2683.0000 - val_true_negatives: 2324949.0000 - val_binary_accuracy: 0.9866
# Epoch 52/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8505 - precision: 0.1308 - recall: 0.2397 - false_negatives: 19369.5467 - false_positives: 41464.3467 - true_positives: 6162.2667 - true_negatives: 4911992.2133 - binary_accuracy: 0.9887 - val_loss: 0.9228 - val_precision: 0.0939 - val_recall: 0.0944 - val_false_negatives: 8518.0000 - val_false_positives: 8570.0000 - val_true_positives: 888.0000 - val_true_negatives: 2341320.0000 - val_binary_accuracy: 0.9928
# Epoch 53/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.9371 - precision: 0.1212 - recall: 0.0663 - false_negatives: 27955.8000 - false_positives: 23937.6267 - true_positives: 2341.1733 - true_negatives: 4924753.7733 - binary_accuracy: 0.9903 - val_loss: 0.9324 - val_precision: 0.0900 - val_recall: 0.0854 - val_false_negatives: 11568.0000 - val_false_positives: 10918.0000 - val_true_positives: 1080.0000 - val_true_negatives: 2335730.0000 - val_binary_accuracy: 0.9905
# Epoch 54/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8724 - precision: 0.1580 - recall: 0.1719 - false_negatives: 18097.9333 - false_positives: 23108.1600 - true_positives: 3853.8533 - true_negatives: 4933928.4267 - binary_accuracy: 0.9925 - val_loss: 0.8800 - val_precision: 0.1323 - val_recall: 0.2003 - val_false_negatives: 10264.0000 - val_false_positives: 16859.0000 - val_true_positives: 2571.0000 - val_true_negatives: 2329602.0000 - val_binary_accuracy: 0.9885
# Epoch 55/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8887 - precision: 0.1154 - recall: 0.2005 - false_negatives: 16081.3067 - false_positives: 35272.6667 - true_positives: 4213.2133 - true_negatives: 4923421.1867 - binary_accuracy: 0.9907 - val_loss: 0.9410 - val_precision: 0.0888 - val_recall: 0.0718 - val_false_negatives: 8693.0000 - val_false_positives: 6899.0000 - val_true_positives: 672.0000 - val_true_negatives: 2343032.0000 - val_binary_accuracy: 0.9934
# Epoch 56/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8771 - precision: 0.1071 - recall: 0.1894 - false_negatives: 15651.6800 - false_positives: 34246.1733 - true_positives: 3811.4133 - true_negatives: 4925279.1067 - binary_accuracy: 0.9902 - val_loss: 0.9230 - val_precision: 0.1605 - val_recall: 0.0663 - val_false_negatives: 9162.0000 - val_false_positives: 3404.0000 - val_true_positives: 651.0000 - val_true_negatives: 2346079.0000 - val_binary_accuracy: 0.9947
# Epoch 57/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8919 - precision: 0.0925 - recall: 0.2298 - false_negatives: 16378.9333 - false_positives: 58453.0667 - true_positives: 5042.8267 - true_negatives: 4899113.5467 - binary_accuracy: 0.9857 - val_loss: 0.9185 - val_precision: 0.0586 - val_recall: 0.1304 - val_false_negatives: 8412.0000 - val_false_positives: 20276.0000 - val_true_positives: 1261.0000 - val_true_negatives: 2329347.0000 - val_binary_accuracy: 0.9878
# Epoch 58/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8805 - precision: 0.1094 - recall: 0.1868 - false_negatives: 18228.0133 - false_positives: 34124.6267 - true_positives: 4287.6800 - true_negatives: 4922348.0533 - binary_accuracy: 0.9895 - val_loss: 0.8755 - val_precision: 0.1304 - val_recall: 0.2497 - val_false_negatives: 10393.0000 - val_false_positives: 23052.0000 - val_true_positives: 3458.0000 - val_true_negatives: 2322393.0000 - val_binary_accuracy: 0.9858
# Epoch 59/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8507 - precision: 0.1426 - recall: 0.2328 - false_negatives: 21710.8400 - false_positives: 39223.0267 - true_positives: 6831.3333 - true_negatives: 4911223.1733 - binary_accuracy: 0.9877 - val_loss: 0.8665 - val_precision: 0.1498 - val_recall: 0.1998 - val_false_negatives: 8464.0000 - val_false_positives: 11997.0000 - val_true_positives: 2114.0000 - val_true_negatives: 2336721.0000 - val_binary_accuracy: 0.9913
# Epoch 60/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8741 - precision: 0.1249 - recall: 0.2044 - false_negatives: 19557.0933 - false_positives: 38271.7067 - true_positives: 5364.9200 - true_negatives: 4915794.6533 - binary_accuracy: 0.9889 - val_loss: 0.8294 - val_precision: 0.1621 - val_recall: 0.2890 - val_false_negatives: 9080.0000 - val_false_positives: 19073.0000 - val_true_positives: 3690.0000 - val_true_negatives: 2327453.0000 - val_binary_accuracy: 0.9881
# Epoch 61/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8328 - precision: 0.1714 - recall: 0.2373 - false_negatives: 20637.6133 - false_positives: 31412.7733 - true_positives: 6277.7467 - true_negatives: 4920660.2400 - binary_accuracy: 0.9897 - val_loss: 0.8285 - val_precision: 0.2530 - val_recall: 0.2612 - val_false_negatives: 9881.0000 - val_false_positives: 10317.0000 - val_true_positives: 3494.0000 - val_true_negatives: 2335604.0000 - val_binary_accuracy: 0.9914
# Epoch 62/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8849 - precision: 0.1522 - recall: 0.1808 - false_negatives: 18217.3200 - false_positives: 22081.9333 - true_positives: 4420.8000 - true_negatives: 4934268.3200 - binary_accuracy: 0.9923 - val_loss: 0.8677 - val_precision: 0.1057 - val_recall: 0.2195 - val_false_negatives: 9715.0000 - val_false_positives: 23113.0000 - val_true_positives: 2732.0000 - val_true_negatives: 2323736.0000 - val_binary_accuracy: 0.9861
# Epoch 63/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8696 - precision: 0.1078 - recall: 0.2299 - false_negatives: 20301.8933 - false_positives: 47807.7600 - true_positives: 6184.7467 - true_negatives: 4904693.9733 - binary_accuracy: 0.9866 - val_loss: 0.8773 - val_precision: 0.0938 - val_recall: 0.2309 - val_false_negatives: 9851.0000 - val_false_positives: 28569.0000 - val_true_positives: 2957.0000 - val_true_negatives: 2317919.0000 - val_binary_accuracy: 0.9837
# Epoch 64/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8821 - precision: 0.1194 - recall: 0.1950 - false_negatives: 17797.2533 - false_positives: 31277.5733 - true_positives: 4411.6000 - true_negatives: 4925501.9467 - binary_accuracy: 0.9901 - val_loss: 0.9053 - val_precision: 0.0760 - val_recall: 0.3289 - val_false_negatives: 6430.0000 - val_false_positives: 38300.0000 - val_true_positives: 3151.0000 - val_true_negatives: 2311415.0000 - val_binary_accuracy: 0.9810
# Epoch 65/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8679 - precision: 0.1332 - recall: 0.2261 - false_negatives: 19928.2400 - false_positives: 33766.2000 - true_positives: 5331.3600 - true_negatives: 4919962.5733 - binary_accuracy: 0.9879 - val_loss: 0.9047 - val_precision: 0.0850 - val_recall: 0.1772 - val_false_negatives: 7775.0000 - val_false_positives: 18025.0000 - val_true_positives: 1674.0000 - val_true_negatives: 2331822.0000 - val_binary_accuracy: 0.9891
# Epoch 66/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8724 - precision: 0.1268 - recall: 0.2186 - false_negatives: 16245.0933 - false_positives: 30144.8000 - true_positives: 4613.9067 - true_negatives: 4927984.5733 - binary_accuracy: 0.9911 - val_loss: 0.7715 - val_precision: 0.2053 - val_recall: 0.3122 - val_false_negatives: 11335.0000 - val_false_positives: 19912.0000 - val_true_positives: 5144.0000 - val_true_negatives: 2322905.0000 - val_binary_accuracy: 0.9868
# Epoch 67/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8558 - precision: 0.1608 - recall: 0.2458 - false_negatives: 21305.8933 - false_positives: 45313.0933 - true_positives: 6861.2667 - true_negatives: 4905508.1200 - binary_accuracy: 0.9873 - val_loss: 0.8381 - val_precision: 0.1868 - val_recall: 0.1637 - val_false_negatives: 13621.0000 - val_false_positives: 11605.0000 - val_true_positives: 2666.0000 - val_true_negatives: 2331404.0000 - val_binary_accuracy: 0.9893
# Epoch 68/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8499 - precision: 0.1939 - recall: 0.2177 - false_negatives: 16586.8800 - false_positives: 21530.6533 - true_positives: 4355.1600 - true_negatives: 4936515.6800 - binary_accuracy: 0.9926 - val_loss: 0.8268 - val_precision: 0.1905 - val_recall: 0.2335 - val_false_negatives: 11216.0000 - val_false_positives: 14519.0000 - val_true_positives: 3416.0000 - val_true_negatives: 2330145.0000 - val_binary_accuracy: 0.9891
# Epoch 69/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8469 - precision: 0.1641 - recall: 0.2216 - false_negatives: 19709.2667 - false_positives: 30047.2667 - true_positives: 6263.6267 - true_negatives: 4922968.2133 - binary_accuracy: 0.9903 - val_loss: 0.8386 - val_precision: 0.2135 - val_recall: 0.2791 - val_false_negatives: 9778.0000 - val_false_positives: 13942.0000 - val_true_positives: 3785.0000 - val_true_negatives: 2331791.0000 - val_binary_accuracy: 0.9899
# Epoch 70/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7630 - precision: 0.2277 - recall: 0.3076 - false_negatives: 25335.2000 - false_positives: 43548.5467 - true_positives: 10853.9333 - true_negatives: 4899250.6933 - binary_accuracy: 0.9864 - val_loss: 0.7928 - val_precision: 0.2441 - val_recall: 0.3072 - val_false_negatives: 10202.0000 - val_false_positives: 14005.0000 - val_true_positives: 4523.0000 - val_true_negatives: 2330566.0000 - val_binary_accuracy: 0.9897
# Epoch 71/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8012 - precision: 0.2280 - recall: 0.2568 - false_negatives: 25830.1333 - false_positives: 34996.4133 - true_positives: 8761.9200 - true_negatives: 4909399.9067 - binary_accuracy: 0.9876 - val_loss: 0.8533 - val_precision: 0.1286 - val_recall: 0.2619 - val_false_negatives: 7547.0000 - val_false_positives: 18148.0000 - val_true_positives: 2678.0000 - val_true_negatives: 2330923.0000 - val_binary_accuracy: 0.9891
# Epoch 72/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8394 - precision: 0.1564 - recall: 0.2184 - false_negatives: 22457.4267 - false_positives: 34824.7067 - true_positives: 6358.9600 - true_negatives: 4915347.2800 - binary_accuracy: 0.9889 - val_loss: 0.8271 - val_precision: 0.1710 - val_recall: 0.2972 - val_false_negatives: 11051.0000 - val_false_positives: 22652.0000 - val_true_positives: 4674.0000 - val_true_negatives: 2320919.0000 - val_binary_accuracy: 0.9857
# Epoch 73/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8319 - precision: 0.1678 - recall: 0.2339 - false_negatives: 21825.1867 - false_positives: 30556.8800 - true_positives: 7024.4800 - true_negatives: 4919581.8267 - binary_accuracy: 0.9894 - val_loss: 0.8000 - val_precision: 0.2054 - val_recall: 0.2438 - val_false_negatives: 11471.0000 - val_false_positives: 14310.0000 - val_true_positives: 3699.0000 - val_true_negatives: 2329816.0000 - val_binary_accuracy: 0.9891
# Epoch 74/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8512 - precision: 0.1615 - recall: 0.2166 - false_negatives: 16677.0133 - false_positives: 22019.0533 - true_positives: 4817.0000 - true_negatives: 4935475.3067 - binary_accuracy: 0.9922 - val_loss: 0.8083 - val_precision: 0.2183 - val_recall: 0.2279 - val_false_negatives: 9571.0000 - val_false_positives: 10118.0000 - val_true_positives: 2825.0000 - val_true_negatives: 2336782.0000 - val_binary_accuracy: 0.9917
# Epoch 75/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7876 - precision: 0.2302 - recall: 0.3226 - false_negatives: 18010.2533 - false_positives: 35380.7733 - true_positives: 7991.5867 - true_negatives: 4917605.7600 - binary_accuracy: 0.9905 - val_loss: 0.8262 - val_precision: 0.1490 - val_recall: 0.3243 - val_false_negatives: 7517.0000 - val_false_positives: 20613.0000 - val_true_positives: 3608.0000 - val_true_negatives: 2327558.0000 - val_binary_accuracy: 0.9881
# Epoch 76/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8222 - precision: 0.1857 - recall: 0.2569 - false_negatives: 21284.6133 - false_positives: 29685.2267 - true_positives: 7369.2000 - true_negatives: 4920649.3333 - binary_accuracy: 0.9898 - val_loss: 0.8260 - val_precision: 0.1616 - val_recall: 0.3076 - val_false_negatives: 8198.0000 - val_false_positives: 18894.0000 - val_true_positives: 3642.0000 - val_true_negatives: 2328562.0000 - val_binary_accuracy: 0.9885
# Epoch 77/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8450 - precision: 0.1595 - recall: 0.2545 - false_negatives: 20050.3067 - false_positives: 33733.8400 - true_positives: 6815.9867 - true_negatives: 4918388.2400 - binary_accuracy: 0.9884 - val_loss: 0.8938 - val_precision: 0.1590 - val_recall: 0.1532 - val_false_negatives: 8438.0000 - val_false_positives: 8076.0000 - val_true_positives: 1527.0000 - val_true_negatives: 2341255.0000 - val_binary_accuracy: 0.9930
# Epoch 78/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8111 - precision: 0.2264 - recall: 0.2679 - false_negatives: 22229.7200 - false_positives: 27601.8667 - true_positives: 8243.9467 - true_negatives: 4920912.8400 - binary_accuracy: 0.9903 - val_loss: 0.7763 - val_precision: 0.2237 - val_recall: 0.2877 - val_false_negatives: 8602.0000 - val_false_positives: 12057.0000 - val_true_positives: 3474.0000 - val_true_negatives: 2335163.0000 - val_binary_accuracy: 0.9912
# Epoch 79/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8609 - precision: 0.1478 - recall: 0.2234 - false_negatives: 19006.4933 - false_positives: 30069.6133 - true_positives: 5713.3867 - true_negatives: 4924198.8800 - binary_accuracy: 0.9903 - val_loss: 0.7871 - val_precision: 0.1778 - val_recall: 0.3904 - val_false_negatives: 6367.0000 - val_false_positives: 18853.0000 - val_true_positives: 4078.0000 - val_true_negatives: 2329998.0000 - val_binary_accuracy: 0.9893
# Epoch 80/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7728 - precision: 0.2278 - recall: 0.2906 - false_negatives: 22177.1867 - false_positives: 29538.4533 - true_positives: 8993.0533 - true_negatives: 4918279.6800 - binary_accuracy: 0.9887 - val_loss: 0.8062 - val_precision: 0.1717 - val_recall: 0.2420 - val_false_negatives: 10115.0000 - val_false_positives: 15581.0000 - val_true_positives: 3230.0000 - val_true_negatives: 2330370.0000 - val_binary_accuracy: 0.9891
# Epoch 81/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7818 - precision: 0.2449 - recall: 0.2503 - false_negatives: 20779.6400 - false_positives: 23277.1467 - true_positives: 6636.8400 - true_negatives: 4928294.7467 - binary_accuracy: 0.9910 - val_loss: 0.8339 - val_precision: 0.1530 - val_recall: 0.2392 - val_false_negatives: 10717.0000 - val_false_positives: 18663.0000 - val_true_positives: 3370.0000 - val_true_negatives: 2326546.0000 - val_binary_accuracy: 0.9875
# Epoch 82/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8028 - precision: 0.1935 - recall: 0.2651 - false_negatives: 17534.1333 - false_positives: 25162.6800 - true_positives: 6731.6267 - true_negatives: 4929559.9333 - binary_accuracy: 0.9911 - val_loss: 0.8240 - val_precision: 0.1813 - val_recall: 0.2589 - val_false_negatives: 7384.0000 - val_false_positives: 11654.0000 - val_true_positives: 2580.0000 - val_true_negatives: 2337678.0000 - val_binary_accuracy: 0.9919
# Epoch 83/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8059 - precision: 0.2219 - recall: 0.2900 - false_negatives: 18396.9333 - false_positives: 25630.8400 - true_positives: 7326.4533 - true_negatives: 4927634.1467 - binary_accuracy: 0.9909 - val_loss: 0.9258 - val_precision: 0.1150 - val_recall: 0.0972 - val_false_negatives: 6567.0000 - val_false_positives: 5441.0000 - val_true_positives: 707.0000 - val_true_negatives: 2346581.0000 - val_binary_accuracy: 0.9949
# Epoch 84/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7922 - precision: 0.2218 - recall: 0.2933 - false_negatives: 18387.9200 - false_positives: 26601.5733 - true_positives: 7951.9200 - true_negatives: 4926046.9600 - binary_accuracy: 0.9914 - val_loss: 0.8503 - val_precision: 0.2927 - val_recall: 0.1709 - val_false_negatives: 7931.0000 - val_false_positives: 3950.0000 - val_true_positives: 1635.0000 - val_true_negatives: 2345780.0000 - val_binary_accuracy: 0.9950
# Epoch 85/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7957 - precision: 0.2072 - recall: 0.3032 - false_negatives: 21862.1200 - false_positives: 39562.8400 - true_positives: 9514.6000 - true_negatives: 4908048.8133 - binary_accuracy: 0.9874 - val_loss: 0.8520 - val_precision: 0.1529 - val_recall: 0.2179 - val_false_negatives: 9792.0000 - val_false_positives: 15114.0000 - val_true_positives: 2728.0000 - val_true_negatives: 2331662.0000 - val_binary_accuracy: 0.9894
# Epoch 86/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7880 - precision: 0.1877 - recall: 0.3026 - false_negatives: 15791.2933 - false_positives: 26549.8533 - true_positives: 6140.0000 - true_negatives: 4930507.2267 - binary_accuracy: 0.9912 - val_loss: 0.8652 - val_precision: 0.1618 - val_recall: 0.1640 - val_false_negatives: 7386.0000 - val_false_positives: 7507.0000 - val_true_positives: 1449.0000 - val_true_negatives: 2342954.0000 - val_binary_accuracy: 0.9937
# Epoch 87/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7999 - precision: 0.2233 - recall: 0.2788 - false_negatives: 13767.4400 - false_positives: 19133.9200 - true_positives: 5363.1200 - true_negatives: 4940723.8933 - binary_accuracy: 0.9937 - val_loss: 0.7957 - val_precision: 0.2784 - val_recall: 0.2318 - val_false_negatives: 11679.0000 - val_false_positives: 9135.0000 - val_true_positives: 3525.0000 - val_true_negatives: 2334957.0000 - val_binary_accuracy: 0.9912
# Epoch 88/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8160 - precision: 0.1950 - recall: 0.2329 - false_negatives: 14676.3333 - false_positives: 21989.2800 - true_positives: 4805.5200 - true_negatives: 4937517.2400 - binary_accuracy: 0.9932 - val_loss: 0.8296 - val_precision: 0.1971 - val_recall: 0.2432 - val_false_negatives: 8410.0000 - val_false_positives: 11010.0000 - val_true_positives: 2703.0000 - val_true_negatives: 2337173.0000 - val_binary_accuracy: 0.9918
# Epoch 89/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8234 - precision: 0.1751 - recall: 0.2897 - false_negatives: 16776.3067 - false_positives: 31489.6400 - true_positives: 6862.5867 - true_negatives: 4923859.8400 - binary_accuracy: 0.9896 - val_loss: 0.7595 - val_precision: 0.3347 - val_recall: 0.2777 - val_false_negatives: 10760.0000 - val_false_positives: 8224.0000 - val_true_positives: 4137.0000 - val_true_negatives: 2336175.0000 - val_binary_accuracy: 0.9920
# Epoch 90/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7812 - precision: 0.2376 - recall: 0.2605 - false_negatives: 17318.1733 - false_positives: 19711.2800 - true_positives: 5981.4267 - true_negatives: 4935977.4933 - binary_accuracy: 0.9926 - val_loss: 0.8468 - val_precision: 0.1859 - val_recall: 0.3061 - val_false_negatives: 6038.0000 - val_false_positives: 11659.0000 - val_true_positives: 2663.0000 - val_true_negatives: 2338936.0000 - val_binary_accuracy: 0.9925
# Epoch 91/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8078 - precision: 0.2086 - recall: 0.2544 - false_negatives: 18345.4400 - false_positives: 22690.9200 - true_positives: 6627.0800 - true_negatives: 4931324.9333 - binary_accuracy: 0.9917 - val_loss: 0.8247 - val_precision: 0.2122 - val_recall: 0.2395 - val_false_negatives: 11049.0000 - val_false_positives: 12914.0000 - val_true_positives: 3479.0000 - val_true_negatives: 2331854.0000 - val_binary_accuracy: 0.9898
# Epoch 92/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7699 - precision: 0.2651 - recall: 0.2622 - false_negatives: 19038.0267 - false_positives: 20736.8667 - true_positives: 6597.1333 - true_negatives: 4932616.3467 - binary_accuracy: 0.9924 - val_loss: 0.8464 - val_precision: 0.1446 - val_recall: 0.2984 - val_false_negatives: 6364.0000 - val_false_positives: 16014.0000 - val_true_positives: 2707.0000 - val_true_negatives: 2334211.0000 - val_binary_accuracy: 0.9905
# Epoch 93/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8093 - precision: 0.1833 - recall: 0.2815 - false_negatives: 17670.0533 - false_positives: 31338.9467 - true_positives: 6638.9333 - true_negatives: 4923340.4400 - binary_accuracy: 0.9902 - val_loss: 0.7855 - val_precision: 0.2453 - val_recall: 0.2864 - val_false_negatives: 7885.0000 - val_false_positives: 9738.0000 - val_true_positives: 3165.0000 - val_true_negatives: 2338508.0000 - val_binary_accuracy: 0.9925
# Epoch 94/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.8127 - precision: 0.2398 - recall: 0.2389 - false_negatives: 20822.3067 - false_positives: 20048.3067 - true_positives: 6389.3067 - true_negatives: 4931728.4533 - binary_accuracy: 0.9920 - val_loss: 0.8193 - val_precision: 0.1528 - val_recall: 0.3069 - val_false_negatives: 6141.0000 - val_false_positives: 15072.0000 - val_true_positives: 2719.0000 - val_true_negatives: 2335364.0000 - val_binary_accuracy: 0.9910
# Epoch 95/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7992 - precision: 0.1894 - recall: 0.2884 - false_negatives: 21712.8533 - false_positives: 38686.8400 - true_positives: 8877.8133 - true_negatives: 4909710.8667 - binary_accuracy: 0.9872 - val_loss: 0.7585 - val_precision: 0.2688 - val_recall: 0.2329 - val_false_negatives: 12618.0000 - val_false_positives: 10419.0000 - val_true_positives: 3831.0000 - val_true_negatives: 2332428.0000 - val_binary_accuracy: 0.9902
# Epoch 96/3000
# ...
# Epoch 177/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7324 - precision: 0.3161 - recall: 0.3014 - false_negatives: 15356.6933 - false_positives: 14019.8667 - true_positives: 6968.8133 - true_negatives: 4942643.0000 - binary_accuracy: 0.9942 - val_loss: 0.7109 - val_precision: 0.2990 - val_recall: 0.4047 - val_false_negatives: 6906.0000 - val_false_positives: 11006.0000 - val_true_positives: 4694.0000 - val_true_negatives: 2336690.0000 - val_binary_accuracy: 0.9924
# Epoch 178/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6961 - precision: 0.3283 - recall: 0.3524 - false_negatives: 16460.5600 - false_positives: 16314.1333 - true_positives: 9230.4267 - true_negatives: 4936983.2533 - binary_accuracy: 0.9935 - val_loss: 0.6049 - val_precision: 0.4583 - val_recall: 0.4226 - val_false_negatives: 10293.0000 - val_false_positives: 8905.0000 - val_true_positives: 7534.0000 - val_true_negatives: 2332564.0000 - val_binary_accuracy: 0.9919
# Epoch 179/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6616 - precision: 0.4411 - recall: 0.4008 - false_negatives: 15211.4133 - false_positives: 13444.0800 - true_positives: 9920.7467 - true_negatives: 4940412.1333 - binary_accuracy: 0.9942 - val_loss: 0.7634 - val_precision: 0.2776 - val_recall: 0.2690 - val_false_negatives: 9842.0000 - val_false_positives: 9426.0000 - val_true_positives: 3622.0000 - val_true_negatives: 2336406.0000 - val_binary_accuracy: 0.9918
# Epoch 180/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6756 - precision: 0.4164 - recall: 0.3590 - false_negatives: 18701.8933 - false_positives: 14449.9467 - true_positives: 10596.1733 - true_negatives: 4935240.3600 - binary_accuracy: 0.9934 - val_loss: 0.7649 - val_precision: 0.3759 - val_recall: 0.2618 - val_false_negatives: 10428.0000 - val_false_positives: 6139.0000 - val_true_positives: 3698.0000 - val_true_negatives: 2339031.0000 - val_binary_accuracy: 0.9930
# Epoch 181/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6964 - precision: 0.3680 - recall: 0.3194 - false_negatives: 17463.7067 - false_positives: 14646.8533 - true_positives: 8643.8400 - true_negatives: 4938233.9733 - binary_accuracy: 0.9938 - val_loss: 0.7231 - val_precision: 0.4175 - val_recall: 0.2583 - val_false_negatives: 8061.0000 - val_false_positives: 3917.0000 - val_true_positives: 2808.0000 - val_true_negatives: 2344510.0000 - val_binary_accuracy: 0.9949
# Epoch 182/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7398 - precision: 0.3872 - recall: 0.2923 - false_negatives: 16782.5867 - false_positives: 12690.0400 - true_positives: 7280.4133 - true_negatives: 4942235.3333 - binary_accuracy: 0.9939 - val_loss: 0.7048 - val_precision: 0.3883 - val_recall: 0.3569 - val_false_negatives: 7326.0000 - val_false_positives: 6405.0000 - val_true_positives: 4065.0000 - val_true_negatives: 2341500.0000 - val_binary_accuracy: 0.9942
# Epoch 183/3000
# 74/74 [==============================] - 8s 105ms/step - loss: 0.6747 - precision: 0.4024 - recall: 0.3624 - false_negatives: 12834.0400 - false_positives: 10403.9200 - true_positives: 7209.3333 - true_negatives: 4948541.0800 - binary_accuracy: 0.9954 - val_loss: 0.7190 - val_precision: 0.3338 - val_recall: 0.2720 - val_false_negatives: 10619.0000 - val_false_positives: 7920.0000 - val_true_positives: 3968.0000 - val_true_negatives: 2336789.0000 - val_binary_accuracy: 0.9921
# Epoch 184/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6492 - precision: 0.3993 - recall: 0.3924 - false_negatives: 13131.9733 - false_positives: 12457.8933 - true_positives: 7824.2533 - true_negatives: 4945574.2533 - binary_accuracy: 0.9946 - val_loss: 0.5825 - val_precision: 0.4388 - val_recall: 0.4724 - val_false_negatives: 8439.0000 - val_false_positives: 9666.0000 - val_true_positives: 7557.0000 - val_true_negatives: 2333634.0000 - val_binary_accuracy: 0.9923
# Epoch 185/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7114 - precision: 0.3935 - recall: 0.3276 - false_negatives: 13838.1200 - false_positives: 10972.3067 - true_positives: 7195.0667 - true_negatives: 4946982.8800 - binary_accuracy: 0.9953 - val_loss: 0.6765 - val_precision: 0.4003 - val_recall: 0.3377 - val_false_negatives: 9716.0000 - val_false_positives: 7423.0000 - val_true_positives: 4954.0000 - val_true_negatives: 2337203.0000 - val_binary_accuracy: 0.9927
# Epoch 186/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6683 - precision: 0.4053 - recall: 0.3439 - false_negatives: 17084.4400 - false_positives: 13402.1600 - true_positives: 8613.5067 - true_negatives: 4939888.2667 - binary_accuracy: 0.9937 - val_loss: 0.6323 - val_precision: 0.3997 - val_recall: 0.3986 - val_false_negatives: 10866.0000 - val_false_positives: 10817.0000 - val_true_positives: 7201.0000 - val_true_negatives: 2330412.0000 - val_binary_accuracy: 0.9908
# Epoch 187/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7084 - precision: 0.3574 - recall: 0.3359 - false_negatives: 17833.5733 - false_positives: 16225.0800 - true_positives: 9009.2267 - true_negatives: 4935920.4933 - binary_accuracy: 0.9934 - val_loss: 0.7170 - val_precision: 0.3245 - val_recall: 0.2680 - val_false_negatives: 7865.0000 - val_false_positives: 5992.0000 - val_true_positives: 2879.0000 - val_true_negatives: 2342560.0000 - val_binary_accuracy: 0.9941
# Epoch 188/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6833 - precision: 0.4189 - recall: 0.3245 - false_negatives: 17804.6000 - false_positives: 12604.1333 - true_positives: 9051.5467 - true_negatives: 4939528.0933 - binary_accuracy: 0.9939 - val_loss: 0.7456 - val_precision: 0.4250 - val_recall: 0.3026 - val_false_negatives: 8412.0000 - val_false_positives: 4939.0000 - val_true_positives: 3650.0000 - val_true_negatives: 2342295.0000 - val_binary_accuracy: 0.9943
# Epoch 189/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6957 - precision: 0.3773 - recall: 0.3407 - false_negatives: 17113.3600 - false_positives: 14921.8133 - true_positives: 8276.4800 - true_negatives: 4938676.7200 - binary_accuracy: 0.9933 - val_loss: 0.7367 - val_precision: 0.3470 - val_recall: 0.2350 - val_false_negatives: 8407.0000 - val_false_positives: 4859.0000 - val_true_positives: 2582.0000 - val_true_negatives: 2343448.0000 - val_binary_accuracy: 0.9944
# Epoch 190/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7179 - precision: 0.3691 - recall: 0.3345 - false_negatives: 18683.5067 - false_positives: 16966.3867 - true_positives: 9618.2533 - true_negatives: 4933720.2267 - binary_accuracy: 0.9933 - val_loss: 0.7346 - val_precision: 0.3134 - val_recall: 0.2948 - val_false_negatives: 9018.0000 - val_false_positives: 8258.0000 - val_true_positives: 3769.0000 - val_true_negatives: 2338251.0000 - val_binary_accuracy: 0.9927
# Epoch 191/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6970 - precision: 0.3595 - recall: 0.3278 - false_negatives: 17755.6133 - false_positives: 15377.0800 - true_positives: 8504.1200 - true_negatives: 4937351.5600 - binary_accuracy: 0.9932 - val_loss: 0.8325 - val_precision: 0.2035 - val_recall: 0.2735 - val_false_negatives: 6824.0000 - val_false_positives: 10056.0000 - val_true_positives: 2569.0000 - val_true_negatives: 2339847.0000 - val_binary_accuracy: 0.9928
# Epoch 192/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7581 - precision: 0.2804 - recall: 0.3354 - false_negatives: 14061.2267 - false_positives: 15891.0133 - true_positives: 6426.5600 - true_negatives: 4942609.5733 - binary_accuracy: 0.9939 - val_loss: 0.7450 - val_precision: 0.3887 - val_recall: 0.2804 - val_false_negatives: 8023.0000 - val_false_positives: 4917.0000 - val_true_positives: 3127.0000 - val_true_negatives: 2343229.0000 - val_binary_accuracy: 0.9945
# Epoch 193/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7032 - precision: 0.3902 - recall: 0.3615 - false_negatives: 15653.9600 - false_positives: 15452.2533 - true_positives: 8804.7200 - true_negatives: 4939077.4400 - binary_accuracy: 0.9937 - val_loss: 0.7786 - val_precision: 0.3233 - val_recall: 0.2563 - val_false_negatives: 7321.0000 - val_false_positives: 5281.0000 - val_true_positives: 2523.0000 - val_true_negatives: 2344171.0000 - val_binary_accuracy: 0.9947
# Epoch 194/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7093 - precision: 0.3712 - recall: 0.3257 - false_negatives: 16319.8000 - false_positives: 12975.9467 - true_positives: 8407.3200 - true_negatives: 4941285.3067 - binary_accuracy: 0.9943 - val_loss: 0.7515 - val_precision: 0.2804 - val_recall: 0.4018 - val_false_negatives: 5707.0000 - val_false_positives: 9837.0000 - val_true_positives: 3833.0000 - val_true_negatives: 2339919.0000 - val_binary_accuracy: 0.9934
# Epoch 195/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6845 - precision: 0.4089 - recall: 0.3446 - false_negatives: 18146.7067 - false_positives: 13464.6533 - true_positives: 9750.7867 - true_negatives: 4937626.2267 - binary_accuracy: 0.9933 - val_loss: 0.6524 - val_precision: 0.3125 - val_recall: 0.5103 - val_false_negatives: 7796.0000 - val_false_positives: 17869.0000 - val_true_positives: 8124.0000 - val_true_negatives: 2325507.0000 - val_binary_accuracy: 0.9891
# Epoch 196/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7474 - precision: 0.3073 - recall: 0.3202 - false_negatives: 14654.4400 - false_positives: 14527.0133 - true_positives: 6585.0667 - true_negatives: 4943221.8533 - binary_accuracy: 0.9942 - val_loss: 0.6981 - val_precision: 0.4784 - val_recall: 0.2925 - val_false_negatives: 9915.0000 - val_false_positives: 4471.0000 - val_true_positives: 4100.0000 - val_true_negatives: 2340810.0000 - val_binary_accuracy: 0.9939
# Epoch 197/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.7085 - precision: 0.3672 - recall: 0.3268 - false_negatives: 18620.2933 - false_positives: 16153.1067 - true_positives: 10284.0000 - true_negatives: 4933930.9733 - binary_accuracy: 0.9934 - val_loss: 0.6257 - val_precision: 0.4295 - val_recall: 0.4019 - val_false_negatives: 10044.0000 - val_false_positives: 8962.0000 - val_true_positives: 6748.0000 - val_true_negatives: 2333542.0000 - val_binary_accuracy: 0.9919
# Epoch 198/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6724 - precision: 0.4120 - recall: 0.3680 - false_negatives: 21771.4800 - false_positives: 18304.7600 - true_positives: 12872.0000 - true_negatives: 4926040.1333 - binary_accuracy: 0.9916 - val_loss: 0.7955 - val_precision: 0.2992 - val_recall: 0.2214 - val_false_negatives: 7264.0000 - val_false_positives: 4840.0000 - val_true_positives: 2066.0000 - val_true_negatives: 2345126.0000 - val_binary_accuracy: 0.9949
# Epoch 199/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6519 - precision: 0.4313 - recall: 0.3804 - false_negatives: 16772.7867 - false_positives: 13298.8133 - true_positives: 9243.8933 - true_negatives: 4939672.8800 - binary_accuracy: 0.9941 - val_loss: 0.7455 - val_precision: 0.2536 - val_recall: 0.3072 - val_false_negatives: 5509.0000 - val_false_positives: 7190.0000 - val_true_positives: 2443.0000 - val_true_negatives: 2344154.0000 - val_binary_accuracy: 0.9946
# Epoch 200/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6948 - precision: 0.3571 - recall: 0.3144 - false_negatives: 20506.6267 - false_positives: 16668.4533 - true_positives: 10153.3200 - true_negatives: 4931659.9733 - binary_accuracy: 0.9926 - val_loss: 0.7828 - val_precision: 0.3089 - val_recall: 0.2785 - val_false_negatives: 4507.0000 - val_false_positives: 3893.0000 - val_true_positives: 1740.0000 - val_true_negatives: 2349156.0000 - val_binary_accuracy: 0.9964
# Epoch 201/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6692 - precision: 0.4037 - recall: 0.3491 - false_negatives: 18555.2000 - false_positives: 14651.0267 - true_positives: 10060.5200 - true_negatives: 4935721.6267 - binary_accuracy: 0.9937 - val_loss: 0.6467 - val_precision: 0.3879 - val_recall: 0.3657 - val_false_negatives: 8073.0000 - val_false_positives: 7345.0000 - val_true_positives: 4654.0000 - val_true_negatives: 2339224.0000 - val_binary_accuracy: 0.9935
# Epoch 202/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6545 - precision: 0.4481 - recall: 0.3970 - false_negatives: 16510.0667 - false_positives: 13301.6400 - true_positives: 10341.2000 - true_negatives: 4938835.4667 - binary_accuracy: 0.9942 - val_loss: 0.7492 - val_precision: 0.2883 - val_recall: 0.3212 - val_false_negatives: 6220.0000 - val_false_positives: 7266.0000 - val_true_positives: 2943.0000 - val_true_negatives: 2342867.0000 - val_binary_accuracy: 0.9943
# Epoch 203/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6668 - precision: 0.4073 - recall: 0.3910 - false_negatives: 16783.4667 - false_positives: 14410.6667 - true_positives: 10283.4400 - true_negatives: 4937510.8000 - binary_accuracy: 0.9937 - val_loss: 0.6307 - val_precision: 0.3900 - val_recall: 0.4098 - val_false_negatives: 6796.0000 - val_false_positives: 7379.0000 - val_true_positives: 4718.0000 - val_true_negatives: 2340403.0000 - val_binary_accuracy: 0.9940
# Epoch 204/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6924 - precision: 0.3913 - recall: 0.3301 - false_negatives: 16562.1600 - false_positives: 12601.6133 - true_positives: 8375.4133 - true_negatives: 4941449.1867 - binary_accuracy: 0.9943 - val_loss: 0.6958 - val_precision: 0.4244 - val_recall: 0.3170 - val_false_negatives: 10477.0000 - val_false_positives: 6596.0000 - val_true_positives: 4863.0000 - val_true_negatives: 2337360.0000 - val_binary_accuracy: 0.9928
# Epoch 205/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6336 - precision: 0.4419 - recall: 0.3641 - false_negatives: 17701.8933 - false_positives: 12872.1733 - true_positives: 10713.5067 - true_negatives: 4937700.8000 - binary_accuracy: 0.9940 - val_loss: 0.7116 - val_precision: 0.3024 - val_recall: 0.3299 - val_false_negatives: 8030.0000 - val_false_positives: 9118.0000 - val_true_positives: 3953.0000 - val_true_negatives: 2338195.0000 - val_binary_accuracy: 0.9927
# Epoch 206/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6866 - precision: 0.3763 - recall: 0.3667 - false_negatives: 17185.7333 - false_positives: 15642.6667 - true_positives: 9850.8933 - true_negatives: 4936309.0800 - binary_accuracy: 0.9933 - val_loss: 0.7493 - val_precision: 0.3982 - val_recall: 0.2616 - val_false_negatives: 8622.0000 - val_false_positives: 4617.0000 - val_true_positives: 3055.0000 - val_true_negatives: 2343002.0000 - val_binary_accuracy: 0.9944
# Epoch 207/3000
# 74/74 [==============================] - 8s 106ms/step - loss: 0.6766 - precision: 0.3703 - recall: 0.3483 - false_negatives: 18481.5467 - false_positives: 17263.9867 - true_positives: 11053.1867 - true_negatives: 4932189.6533 - binary_accuracy: 0.9931 - val_loss: 0.6615 - val_precision: 0.4115 - val_recall: 0.3914 - val_false_negatives: 8807.0000 - val_false_positives: 8102.0000 - val_true_positives: 5665.0000 - val_true_negatives: 2336722.0000 - val_binary_accuracy: 0.9928
# Epoch 208/3000
# 28/74 [==========>...................] - ETA: 4s - loss: 0.6142 - precision: 0.4394 - recall: 0.3760 - false_negatives: 7731.3929 - false_positives: 5558.8929 - true_positives: 4581.6429 - true_negatives: 1882672.0714 - binary_accuracy: 0.9931

# %% [markdown]
# ## unet.save_weights(Models_path+'model')
# #unet = tf.keras.models.load_model(Models_path+'model')

# %%
fig, axs = plt.subplots(2,2, figsize=(15,15))

axs[0,0].plot(model_history.history['binary_accuracy'])
axs[0,0].plot(model_history.history['val_binary_accuracy'])
axs[0,0].set_title('model accuracy')
axs[0,0].set_ylabel('accuracy')

#axs[0].legend(['train', 'val'], loc='upper left')
#axs[0].show()





F1 = 2*np.divide(np.multiply(model_history.history['precision'],model_history.history['recall']), np.add(model_history.history['precision'], model_history.history['recall']))
F1_val = 2*np.divide(np.multiply(model_history.history['val_precision'],model_history.history['val_recall']), np.add(model_history.history['val_precision'], model_history.history['val_recall']))
FP = model_history.history['false_positives']
TP = model_history.history['true_positives']
FN = model_history.history['false_negatives']
TN = model_history.history['true_negatives']
IOU = np.divide(TP,np.add(FN,np.add(TP,FP)))
MCC = np.subtract(np.multiply(TP,TN),np.multiply(FP,FN))/np.sqrt(np.multiply(np.multiply(np.add(TP,FP),np.add(TP,FN)), np.multiply(np.add(TN,FP),np.add(TN,FN))))
FP = model_history.history['val_false_positives']
TP = model_history.history['val_true_positives']
FN = model_history.history['val_false_negatives']
TN = model_history.history['val_true_negatives']
MCC_val = np.subtract(np.multiply(TP,TN),np.multiply(FP,FN))/np.sqrt(np.multiply(np.multiply(np.add(TP,FP),np.add(TP,FN)), np.multiply(np.add(TN,FP),np.add(TN,FN))))
IOU_val = np.divide(TP,np.add(FN,np.add(TP,FP)))

axs[1,0].plot(IOU)
axs[1,0].plot(IOU_val)
axs[1,0].set_title('model IoU')
axs[1,0].set_ylabel('IoU')
axs[1,0].legend(['train', 'val'], loc='upper right')

axs[0,1].plot(F1)
axs[0,1].plot(F1_val)
axs[0,1].set_title('model F1 score')
axs[0,1].set_ylabel('F1')
axs[0,1].set_xlabel('epoch')

axs[1,1].plot(MCC)
axs[1,1].plot(MCC_val)
axs[1,1].set_title('model MCC')
axs[1,1].set_ylabel('MCC')
axs[1,1].set_xlabel('epoch')


i = 1
while os.path.exists(Models_path+"Model%s.png" % i):
    i += 1
plt.savefig(Models_path+"Model%s.png" % i)

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    #print(pred_mask.shape)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

def show_predictions(dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image[tf.newaxis,:,:,:])
            print(mask)
            test=  np.squeeze(pred_mask)
            print(test.shape)
            #display([image, mask, test])
            display([image, mask, create_mask(pred_mask)])
    else:
        display([sample_image, sample_mask,
             create_mask(unet.predict(sample_image[tf.newaxis, ...]))])

# %%
testdataset = get_dataset_large(tfr_dir = TFrecord_path, pattern = '*.tfrecords')
print(testdataset)
show_predictions(testdataset, 10)

#####################change display to show 11microns -12 microns or whatever it should be

# %%
pr_mask = unet.predict(image[tf.newaxis,:,:,:])
plt.imshow(
    pr_mask[0]
)
plt.colorbar()
